# %%
cd ~
mkdir maumee-dashboard
cd maumee-dashboard

git init
git branch -M main

touch README.md .gitignore app.py requirements.txt
mkdir data data_access components scripts

git add .
git commit -m "Initial project structure"

git remote add origin YOUR_REPO_URL
git push -u origin main
# Out:
#   Cell In[2], line 1
#     cd ~
#        ^
# SyntaxError: invalid syntax

# %%
# Test: add this to app.py

import streamlit as st

st.set_page_config(page_title="Maumee Dashboard", layout="wide")

st.title("Maumee Dashboard")
st.write("Streamlit is working.")

# %% [markdown]
# ## START BUILDING THE DASHBOARD (OH ONLY) - VERSION 1

# %%
# Run this in bash after creating the buil_oh file

source venv/bin/activate
pip install geopandas openpyxl pyarrow fiona
python scripts/build_oh_covercrop_v1.py

# Before running the updated app.py file, install:
source venv/bin/activate
pip install pydeck geopandas openpyxl fiona
python scripts/build_oh_covercrop_v1.py


# To run the app:
streamlit run app.py

# %%
## When connecting to Ubuntu (to enter the password)
sudo mkdir -p /mnt/z

## then mount to OSU shared drive
sudo mount -t drvfs '\\files.udstor.it.osu.edu\faes-ncm' /mnt/z

## test if it's connected
ls /mnt/z
ls /mnt/z/users
ls /mnt/z/users/ganbat.3
ls /mnt/z/users/ganbat.3/Regrow
